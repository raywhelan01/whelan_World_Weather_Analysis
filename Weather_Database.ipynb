# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# %%
#Step 2
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Step 3
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 628

# %%
#Steps 4 & 5
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"].capitalize()
        try:
            city_rain = city_weather["rain"]["3h"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["3h"]
        except:
            city_snow = 0
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,
                          "Rain Inches (Last 3 hrs)": city_rain,
                          "Snow Inches (Last 3 hrs)": city_snow})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | leshukonskoye
# Processing Record 5 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 6 of Set 1 | tilichiki
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | kushmurun
# City not found. Skipping...
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | maldonado
# Processing Record 13 of Set 1 | sabang
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | plyussa
# Processing Record 16 of Set 1 | korla
# City not found. Skipping...
# Processing Record 17 of Set 1 | jefferson city
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | horasan
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | marrakesh
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | kahului
# Processing Record 33 of Set 1 | manokwari
# Processing Record 34 of Set 1 | comodoro rivadavia
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | bonthe
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | rio tuba
# Processing Record 39 of Set 1 | kemijarvi
# City not found. Skipping...
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | kathu
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | beira
# Processing Record 50 of Set 1 | maningrida
# Processing Record 1 of Set 2 | yeniseysk
# Processing Record 2 of Set 2 | valparaiso
# Processing Record 3 of Set 2 | wiarton
# Processing Record 4 of Set 2 | sadove
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | plettenberg bay
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | dujuma
# City not found. Skipping...
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 2 | hami
# Processing Record 14 of Set 2 | sukumo
# Processing Record 15 of Set 2 | faya
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | san cristobal
# Processing Record 18 of Set 2 | cayenne
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | sao joao da barra
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | okhotsk
# Processing Record 24 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 2 | sur
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | nara
# Processing Record 30 of Set 2 | palana
# Processing Record 31 of Set 2 | shache
# Processing Record 32 of Set 2 | strezhevoy
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | kirakira
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | tonantins
# Processing Record 37 of Set 2 | las lomas
# Processing Record 38 of Set 2 | churu
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | aksu
# Processing Record 42 of Set 2 | ponta do sol
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | fairbanks
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | puerto carreno
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | tateyama
# Processing Record 49 of Set 2 | bilma
# Processing Record 50 of Set 2 | estremoz
# Processing Record 1 of Set 3 | tasiilaq
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | itaituba
# Processing Record 5 of Set 3 | sun valley
# Processing Record 6 of Set 3 | matadi
# Processing Record 7 of Set 3 | badgam
# City not found. Skipping...
# Processing Record 8 of Set 3 | nikolayevka
# Processing Record 9 of Set 3 | alyangula
# Processing Record 10 of Set 3 | hirara
# Processing Record 11 of Set 3 | avarua
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | lata
# Processing Record 14 of Set 3 | khani
# Processing Record 15 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 3 | sokoto
# Processing Record 17 of Set 3 | muros
# Processing Record 18 of Set 3 | bunbury
# Processing Record 19 of Set 3 | trairi
# Processing Record 20 of Set 3 | nanma
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | georgetown
# Processing Record 23 of Set 3 | chapais
# Processing Record 24 of Set 3 | makasar
# Processing Record 25 of Set 3 | lielvarde
# Processing Record 26 of Set 3 | tambopata
# City not found. Skipping...
# Processing Record 27 of Set 3 | puerto ayora
# Processing Record 28 of Set 3 | san juan
# Processing Record 29 of Set 3 | adrar
# Processing Record 30 of Set 3 | lagoa
# Processing Record 31 of Set 3 | sem
# Processing Record 32 of Set 3 | waingapu
# Processing Record 33 of Set 3 | vila
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | hamina
# Processing Record 36 of Set 3 | port lincoln
# Processing Record 37 of Set 3 | port hardy
# Processing Record 38 of Set 3 | sim
# Processing Record 39 of Set 3 | huaraz
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | olafsvik
# City not found. Skipping...
# Processing Record 43 of Set 3 | jamestown
# Processing Record 44 of Set 3 | pevek
# Processing Record 45 of Set 3 | reconquista
# Processing Record 46 of Set 3 | tura
# Processing Record 47 of Set 3 | smidovich
# Processing Record 48 of Set 3 | ostrovnoy
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | byron bay
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | friesach
# Processing Record 3 of Set 4 | severo-kurilsk
# Processing Record 4 of Set 4 | smolyaninovo
# Processing Record 5 of Set 4 | dingle
# Processing Record 6 of Set 4 | campana
# Processing Record 7 of Set 4 | maniitsoq
# Processing Record 8 of Set 4 | namasuba
# Processing Record 9 of Set 4 | kyabe
# Processing Record 10 of Set 4 | labuhan
# Processing Record 11 of Set 4 | touros
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | mehamn
# Processing Record 17 of Set 4 | vitim
# Processing Record 18 of Set 4 | aswan
# Processing Record 19 of Set 4 | laiagam
# City not found. Skipping...
# Processing Record 20 of Set 4 | santiago
# Processing Record 21 of Set 4 | shirokiy
# Processing Record 22 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 4 | phonhong
# Processing Record 24 of Set 4 | haradok
# Processing Record 25 of Set 4 | niquero
# Processing Record 26 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | luderitz
# Processing Record 30 of Set 4 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 31 of Set 4 | dukat
# Processing Record 32 of Set 4 | santo antonio do ica
# Processing Record 33 of Set 4 | sorland
# Processing Record 34 of Set 4 | airai
# Processing Record 35 of Set 4 | miri
# Processing Record 36 of Set 4 | labuan
# Processing Record 37 of Set 4 | hasaki
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | lumbac
# Processing Record 40 of Set 4 | havre
# Processing Record 41 of Set 4 | naryan-mar
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | flinders
# Processing Record 44 of Set 4 | fort nelson
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | pemangkat
# City not found. Skipping...
# Processing Record 47 of Set 4 | cap malheureux
# Processing Record 48 of Set 4 | eenhana
# Processing Record 49 of Set 4 | oksfjord
# Processing Record 50 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 5 | prince rupert
# Processing Record 2 of Set 5 | saint-francois
# Processing Record 3 of Set 5 | upata
# Processing Record 4 of Set 5 | khashuri
# Processing Record 5 of Set 5 | sibolga
# Processing Record 6 of Set 5 | olinda
# Processing Record 7 of Set 5 | necochea
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | kungurtug
# Processing Record 12 of Set 5 | qunduz
# City not found. Skipping...
# Processing Record 13 of Set 5 | pak phanang
# Processing Record 14 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 5 | ugoofaaru
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | marzuq
# Processing Record 18 of Set 5 | soe
# Processing Record 19 of Set 5 | kifri
# Processing Record 20 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 5 | kampot
# Processing Record 22 of Set 5 | bavly
# Processing Record 23 of Set 5 | rocha
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | buala
# Processing Record 26 of Set 5 | akodia
# Processing Record 27 of Set 5 | samarai
# Processing Record 28 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | zalesovo
# Processing Record 31 of Set 5 | najran
# Processing Record 32 of Set 5 | lebyazhye
# Processing Record 33 of Set 5 | mae sai
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | polyarnyy
# Processing Record 36 of Set 5 | zalalovo
# Processing Record 37 of Set 5 | kamyzyak
# Processing Record 38 of Set 5 | safford
# Processing Record 39 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 5 | arraial do cabo
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | coihaique
# Processing Record 43 of Set 5 | pochutla
# Processing Record 44 of Set 5 | nixa
# Processing Record 45 of Set 5 | figeac
# Processing Record 46 of Set 5 | maceio
# Processing Record 47 of Set 5 | yanam
# Processing Record 48 of Set 5 | simbahan
# Processing Record 49 of Set 5 | bedesa
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | kargil
# Processing Record 2 of Set 6 | svetlogorsk
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | batemans bay
# Processing Record 5 of Set 6 | skelleftea
# Processing Record 6 of Set 6 | taoudenni
# Processing Record 7 of Set 6 | kapaa
# Processing Record 8 of Set 6 | tiznit
# Processing Record 9 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 6 | zhengjiatun
# Processing Record 12 of Set 6 | katherine
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | ulladulla
# Processing Record 15 of Set 6 | ilulissat
# Processing Record 16 of Set 6 | kichera
# Processing Record 17 of Set 6 | sao paulo de olivenca
# Processing Record 18 of Set 6 | nanyang
# Processing Record 19 of Set 6 | yar-sale
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | lalsot
# Processing Record 22 of Set 6 | namatanai
# Processing Record 23 of Set 6 | eslov
# Processing Record 24 of Set 6 | moose factory
# Processing Record 25 of Set 6 | veydelevka
# Processing Record 26 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 6 | sao miguel
# Processing Record 28 of Set 6 | zhanaozen
# Processing Record 29 of Set 6 | great bend
# Processing Record 30 of Set 6 | culfa
# Processing Record 31 of Set 6 | wasilla
# Processing Record 32 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 6 | akyab
# City not found. Skipping...
# Processing Record 34 of Set 6 | pershotravneve
# Processing Record 35 of Set 6 | lavrentiya
# Processing Record 36 of Set 6 | champerico
# Processing Record 37 of Set 6 | bulgan
# Processing Record 38 of Set 6 | tulun
# Processing Record 39 of Set 6 | lugoba
# Processing Record 40 of Set 6 | djibo
# Processing Record 41 of Set 6 | guerrero negro
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 44 of Set 6 | krk
# Processing Record 45 of Set 6 | kenai
# Processing Record 46 of Set 6 | poum
# Processing Record 47 of Set 6 | gamba
# Processing Record 48 of Set 6 | mayskiy
# Processing Record 49 of Set 6 | derzhavinsk
# Processing Record 50 of Set 6 | waipawa
# Processing Record 1 of Set 7 | la sarre
# Processing Record 2 of Set 7 | nisia floresta
# Processing Record 3 of Set 7 | ginda
# Processing Record 4 of Set 7 | jalu
# Processing Record 5 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 7 | ambilobe
# Processing Record 7 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 7 | upernavik
# Processing Record 9 of Set 7 | new norfolk
# Processing Record 10 of Set 7 | padang
# Processing Record 11 of Set 7 | chauk
# Processing Record 12 of Set 7 | edd
# Processing Record 13 of Set 7 | komsomolskiy
# Processing Record 14 of Set 7 | marathopolis
# City not found. Skipping...
# Processing Record 15 of Set 7 | la orilla
# Processing Record 16 of Set 7 | wajir
# Processing Record 17 of Set 7 | grand gaube
# Processing Record 18 of Set 7 | clarksburg
# Processing Record 19 of Set 7 | camacupa
# Processing Record 20 of Set 7 | russkaya polyana
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | honiara
# Processing Record 23 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 7 | gizo
# Processing Record 26 of Set 7 | lingao
# Processing Record 27 of Set 7 | gannan
# Processing Record 28 of Set 7 | durusu
# Processing Record 29 of Set 7 | vila velha
# Processing Record 30 of Set 7 | pingshan
# Processing Record 31 of Set 7 | anqing
# Processing Record 32 of Set 7 | roebourne
# Processing Record 33 of Set 7 | lompoc
# Processing Record 34 of Set 7 | clyde river
# Processing Record 35 of Set 7 | pacifica
# Processing Record 36 of Set 7 | carballo
# Processing Record 37 of Set 7 | avera
# Processing Record 38 of Set 7 | vanimo
# Processing Record 39 of Set 7 | abu zabad
# Processing Record 40 of Set 7 | barcelos
# Processing Record 41 of Set 7 | los llanos de aridane
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | maniwaki
# Processing Record 44 of Set 7 | saint george
# Processing Record 45 of Set 7 | banda aceh
# Processing Record 46 of Set 7 | san quintin
# Processing Record 47 of Set 7 | mount gambier
# Processing Record 48 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | fomboni
# Processing Record 2 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 8 | guanica
# Processing Record 4 of Set 8 | deputatskiy
# Processing Record 5 of Set 8 | kikwit
# Processing Record 6 of Set 8 | butia
# Processing Record 7 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 8 of Set 8 | nouakchott
# Processing Record 9 of Set 8 | tabuk
# Processing Record 10 of Set 8 | tupik
# Processing Record 11 of Set 8 | berwick
# Processing Record 12 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 8 | correntina
# Processing Record 14 of Set 8 | luganville
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | hovd
# Processing Record 17 of Set 8 | bubaque
# Processing Record 18 of Set 8 | ahipara
# Processing Record 19 of Set 8 | havelock
# Processing Record 20 of Set 8 | alihe
# Processing Record 21 of Set 8 | kalengwa
# Processing Record 22 of Set 8 | antofagasta
# Processing Record 23 of Set 8 | yithion
# City not found. Skipping...
# Processing Record 24 of Set 8 | ugarcin
# City not found. Skipping...
# Processing Record 25 of Set 8 | doka
# Processing Record 26 of Set 8 | hearst
# Processing Record 27 of Set 8 | agadez
# Processing Record 28 of Set 8 | pacific grove
# Processing Record 29 of Set 8 | axim
# Processing Record 30 of Set 8 | provideniya
# Processing Record 31 of Set 8 | vostochnyy
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | dinajpur
# Processing Record 34 of Set 8 | berbera
# City not found. Skipping...
# Processing Record 35 of Set 8 | elko
# Processing Record 36 of Set 8 | hamilton
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | vyshneve
# Processing Record 39 of Set 8 | leningradskiy
# Processing Record 40 of Set 8 | mogadishu
# Processing Record 41 of Set 8 | abnub
# Processing Record 42 of Set 8 | taksimo
# Processing Record 43 of Set 8 | mar del plata
# Processing Record 44 of Set 8 | gilgit
# Processing Record 45 of Set 8 | thunder bay
# Processing Record 46 of Set 8 | havoysund
# Processing Record 47 of Set 8 | vao
# Processing Record 48 of Set 8 | iwanai
# Processing Record 49 of Set 8 | nuuk
# Processing Record 50 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 9 | gazanjyk
# Processing Record 2 of Set 9 | karla
# Processing Record 3 of Set 9 | pedernales
# Processing Record 4 of Set 9 | mao
# Processing Record 5 of Set 9 | chelbasskaya
# Processing Record 6 of Set 9 | colares
# Processing Record 7 of Set 9 | skagen
# Processing Record 8 of Set 9 | iquitos
# Processing Record 9 of Set 9 | lucapa
# Processing Record 10 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 9 | goderich
# Processing Record 13 of Set 9 | sakakah
# City not found. Skipping...
# Processing Record 14 of Set 9 | mwene-ditu
# Processing Record 15 of Set 9 | sao filipe
# Processing Record 16 of Set 9 | neyshabur
# Processing Record 17 of Set 9 | oussouye
# Processing Record 18 of Set 9 | kutum
# Processing Record 19 of Set 9 | katangli
# Processing Record 20 of Set 9 | madang
# Processing Record 21 of Set 9 | mersing
# Processing Record 22 of Set 9 | santo tomas
# Processing Record 23 of Set 9 | maragheh
# Processing Record 24 of Set 9 | pithora
# Processing Record 25 of Set 9 | gillette
# Processing Record 26 of Set 9 | grindavik
# Processing Record 27 of Set 9 | surami
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | berlevag
# Processing Record 30 of Set 9 | constitucion
# Processing Record 31 of Set 9 | katsuura
# Processing Record 32 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 9 | lehututu
# Processing Record 34 of Set 9 | bacolod
# Processing Record 35 of Set 9 | erdenet
# Processing Record 36 of Set 9 | benicarlo
# Processing Record 37 of Set 9 | sept-iles
# Processing Record 38 of Set 9 | chicama
# Processing Record 39 of Set 9 | mezen
# Processing Record 40 of Set 9 | verkhnyaya sinyachikha
# Processing Record 41 of Set 9 | agadir
# Processing Record 42 of Set 9 | seoul
# Processing Record 43 of Set 9 | cairns
# Processing Record 44 of Set 9 | suluq
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | manggar
# Processing Record 47 of Set 9 | canilla
# Processing Record 48 of Set 9 | mirnyy
# Processing Record 49 of Set 9 | codrington
# Processing Record 50 of Set 9 | willowmore
# Processing Record 1 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 10 | kondinskoye
# Processing Record 3 of Set 10 | praia
# Processing Record 4 of Set 10 | lagunas
# Processing Record 5 of Set 10 | kudymkar
# Processing Record 6 of Set 10 | port said
# Processing Record 7 of Set 10 | aasiaat
# Processing Record 8 of Set 10 | santa maria del oro
# Processing Record 9 of Set 10 | rozivka
# Processing Record 10 of Set 10 | opuwo
# Processing Record 11 of Set 10 | pierre
# Processing Record 12 of Set 10 | bethel
# Processing Record 13 of Set 10 | inyonga
# Processing Record 14 of Set 10 | darhan
# Processing Record 15 of Set 10 | alofi
# Processing Record 16 of Set 10 | puerto colombia
# Processing Record 17 of Set 10 | vedi
# Processing Record 18 of Set 10 | la palma
# Processing Record 19 of Set 10 | punta de bombon
# Processing Record 20 of Set 10 | mazagao
# Processing Record 21 of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record 22 of Set 10 | hualmay
# Processing Record 23 of Set 10 | egvekinot
# Processing Record 24 of Set 10 | hambantota
# Processing Record 25 of Set 10 | konigs wusterhausen
# Processing Record 26 of Set 10 | melfi
# Processing Record 27 of Set 10 | raton
# Processing Record 28 of Set 10 | manaure
# Processing Record 29 of Set 10 | broken hill
# Processing Record 30 of Set 10 | bac lieu
# City not found. Skipping...
# Processing Record 31 of Set 10 | oktyabrskiy
# Processing Record 32 of Set 10 | degtyarsk
# Processing Record 33 of Set 10 | boyuibe
# Processing Record 34 of Set 10 | tazovskiy
# Processing Record 35 of Set 10 | sungai besar
# Processing Record 36 of Set 10 | lensk
# Processing Record 37 of Set 10 | thai binh
# Processing Record 38 of Set 10 | eureka
# Processing Record 39 of Set 10 | diamantino
# Processing Record 40 of Set 10 | winnemucca
# Processing Record 41 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 42 of Set 10 | polson
# Processing Record 43 of Set 10 | virginia beach
# Processing Record 44 of Set 10 | nome
# Processing Record 45 of Set 10 | kulu
# Processing Record 46 of Set 10 | tigil
# Processing Record 47 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 10 | brae
# Processing Record 49 of Set 10 | osmena
# Processing Record 50 of Set 10 | robertsport
# Processing Record 1 of Set 11 | flin flon
# Processing Record 2 of Set 11 | shenjiamen
# Processing Record 3 of Set 11 | umm lajj
# Processing Record 4 of Set 11 | cleethorpes
# Processing Record 5 of Set 11 | tuatapere
# Processing Record 6 of Set 11 | mount isa
# Processing Record 7 of Set 11 | alta floresta
# Processing Record 8 of Set 11 | west wendover
# Processing Record 9 of Set 11 | murgab
# Processing Record 10 of Set 11 | miranda
# Processing Record 11 of Set 11 | gat
# Processing Record 12 of Set 11 | gibara
# Processing Record 13 of Set 11 | chenghai
# Processing Record 14 of Set 11 | bojonegoro
# Processing Record 15 of Set 11 | meulaboh
# Processing Record 16 of Set 11 | arlo
# Processing Record 17 of Set 11 | burgeo
# Processing Record 18 of Set 11 | bonoua
# Processing Record 19 of Set 11 | port blair
# Processing Record 20 of Set 11 | pundaguitan
# Processing Record 21 of Set 11 | sao miguel do araguaia
# Processing Record 22 of Set 11 | altay
# Processing Record 23 of Set 11 | imbituba
# Processing Record 24 of Set 11 | kieta
# Processing Record 25 of Set 11 | esmeralda
# Processing Record 26 of Set 11 | aljezur
# Processing Record 27 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 28 of Set 11 | uulu
# Processing Record 29 of Set 11 | sisimiut
# Processing Record 30 of Set 11 | korsakov
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | port hueneme
# Processing Record 34 of Set 11 | goure
# Processing Record 35 of Set 11 | salinopolis
# Processing Record 36 of Set 11 | donskoye
# Processing Record 37 of Set 11 | semporna
# Processing Record 38 of Set 11 | nizwa
# Processing Record 39 of Set 11 | uruzgan
# Processing Record 40 of Set 11 | jalalabad
# Processing Record 41 of Set 11 | fare
# Processing Record 42 of Set 11 | mangaratiba
# Processing Record 43 of Set 11 | hare bay
# Processing Record 44 of Set 11 | mobaye
# Processing Record 45 of Set 11 | superior
# Processing Record 46 of Set 11 | kariai
# Processing Record 47 of Set 11 | wanning
# Processing Record 48 of Set 11 | sheltozero
# Processing Record 49 of Set 11 | havre-saint-pierre
# Processing Record 50 of Set 11 | ushumun
# Processing Record 1 of Set 12 | gabu
# Processing Record 2 of Set 12 | mecca
# Processing Record 3 of Set 12 | banjar
# Processing Record 4 of Set 12 | asau
# City not found. Skipping...
# Processing Record 5 of Set 12 | gwadar
# Processing Record 6 of Set 12 | chengde
# Processing Record 7 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 12 | port macquarie
# Processing Record 9 of Set 12 | khristoforovo
# City not found. Skipping...
# Processing Record 10 of Set 12 | magistralnyy
# Processing Record 11 of Set 12 | sayat
# Processing Record 12 of Set 12 | mineros
# Processing Record 13 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 12 | jumla
# Processing Record 15 of Set 12 | roros
# Processing Record 16 of Set 12 | porto empedocle
# Processing Record 17 of Set 12 | chernyshevskiy
# Processing Record 18 of Set 12 | bambanglipuro
# Processing Record 19 of Set 12 | oranjemund
# Processing Record 20 of Set 12 | san patricio
# Processing Record 21 of Set 12 | nishihara
# Processing Record 22 of Set 12 | achkhoy-martan
# Processing Record 23 of Set 12 | brejo
# Processing Record 24 of Set 12 | sant julia de loria
# Processing Record 25 of Set 12 | carauari
# Processing Record 26 of Set 12 | rio grande
# Processing Record 27 of Set 12 | hunchun
# Processing Record 28 of Set 12 | san jose
# Processing Record 29 of Set 12 | aripuana
# Processing Record 30 of Set 12 | kaka
# Processing Record 31 of Set 12 | zhangye
# Processing Record 32 of Set 12 | liwale
# Processing Record 33 of Set 12 | rubtsovsk
# Processing Record 34 of Set 12 | condega
# Processing Record 35 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 36 of Set 12 | narsaq
# Processing Record 37 of Set 12 | atasu
# Processing Record 38 of Set 12 | trat
# Processing Record 39 of Set 12 | katobu
# Processing Record 40 of Set 12 | delmas
# Processing Record 41 of Set 12 | vostok
# Processing Record 42 of Set 12 | laguna
# Processing Record 43 of Set 12 | vysha
# Processing Record 44 of Set 12 | calatayud
# Processing Record 45 of Set 12 | arman
# Processing Record 46 of Set 12 | misratah
# Processing Record 47 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 12 | zatoka
# Processing Record 49 of Set 12 | ringebu
# Processing Record 50 of Set 12 | acatic
# Processing Record 1 of Set 13 | kurchum
# Processing Record 2 of Set 13 | tougan
# Processing Record 3 of Set 13 | mayahi
# Processing Record 4 of Set 13 | harper
# Processing Record 5 of Set 13 | balkhash
# Processing Record 6 of Set 13 | nanortalik
# Processing Record 7 of Set 13 | cabedelo
# Processing Record 8 of Set 13 | ojinaga
# Processing Record 9 of Set 13 | phuket
# Processing Record 10 of Set 13 | kalininskaya
# Processing Record 11 of Set 13 | murray bridge
# Processing Record 12 of Set 13 | mokhsogollokh
# Processing Record 13 of Set 13 | penarroya-pueblonuevo
# Processing Record 14 of Set 13 | voi
# Processing Record 15 of Set 13 | wonthaggi
# Processing Record 16 of Set 13 | jodiya
# Processing Record 17 of Set 13 | springfield
# Processing Record 18 of Set 13 | kathmandu
# Processing Record 19 of Set 13 | yumen
# Processing Record 20 of Set 13 | ormara
# Processing Record 21 of Set 13 | orasje
# Processing Record 22 of Set 13 | cabrobo
# Processing Record 23 of Set 13 | lashio
# Processing Record 24 of Set 13 | isabela
# Processing Record 25 of Set 13 | kidal
# Processing Record 26 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 27 of Set 13 | fairview
# Processing Record 28 of Set 13 | praia da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Step 6
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0     Yellowknife      CA  2019-11-08 19:33:40  62.45 -114.38     12.20
# 1         Ushuaia      AR  2019-11-08 19:27:03 -54.81  -68.31     42.80
# 2   Leshukonskoye      RU  2019-11-08 19:33:41  64.90   45.76     15.87
# 3       Tilichiki      RU  2019-11-08 19:33:41  60.47  166.10     18.09
# 4    Longyearbyen      NO  2019-11-08 19:33:42  78.22   15.63     30.20
# 5  Saint-Philippe      CA  2019-11-08 19:33:42  45.36  -73.48     33.01
# 6          Kodiak      US  2019-11-08 19:33:42  39.95  -94.76     44.01
# 7        Hermanus      ZA  2019-11-08 19:33:43 -34.42   19.24     66.99
# 8       Maldonado      UY  2019-11-08 19:33:26 -34.91  -54.96     69.80
# 9          Sabang      PH  2019-11-08 19:33:43  13.80  121.11     81.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        78          40       11.41    Scattered clouds
# 1        91          75       29.97         Shower rain
# 2        87         100        5.93     Overcast clouds
# 3        77         100       10.58     Overcast clouds
# 4        58          75       28.86       Broken clouds
# 5        63          75       16.11   Light shower snow
# 6        33           1       10.29           Clear sky
# 7        76         100       13.00     Overcast clouds
# 8        60          66       12.75       Broken clouds
# 9        90          91        3.00          Light rain
#
#    Rain Inches (Last 3 hrs)  Snow Inches (Last 3 hrs)
# 0                      0.00                       0.0
# 1                      0.00                       0.0
# 2                      0.00                       0.0
# 3                      0.00                       0.0
# 4                      0.00                       0.0
# 5                      0.00                       0.0
# 6                      0.00                       0.0
# 7                      0.00                       0.0
# 8                      0.00                       0.0
# 9                      0.31                       0.0

# %%
#Step 7
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Step 8
precip_cities = city_data_df.loc[(city_data_df["Rain Inches (Last 3 hrs)"]>0) | (city_data_df["Snow Inches (Last 3 hrs)"]>0)]
precip_cities["City"].count()
# Out:
# 60
